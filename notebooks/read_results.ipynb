# %% [markdown]
# # Extract search results

# %%
import pickle
import pandas
import numpy as np
import torch
from torch import nn

import os, sys
sys.path.append("../")

import search_state
from main import compile_fn
# Out:
# /home/lericsso/miniconda3/envs/einspace/lib/python3.10/site-packages/onnxscript/converter.py:823: FutureWarning: 'onnxscript.values.Op.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()
# /home/lericsso/miniconda3/envs/einspace/lib/python3.10/site-packages/onnxscript/converter.py:823: FutureWarning: 'onnxscript.values.OnnxFunction.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()

# %% [markdown]
# #### Unzip the search results

# %%
# !unzip -o -q results.zip -d ./

# %% [markdown]
# #### list of paths to finished experiments

# %%
paths = [
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/addnist/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/addnist/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/addnist/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/addnist/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/addnist/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/addnist/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=False/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=0/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/addnist/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/addnist/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=1.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/addnist/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/addnist/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=4/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=False/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.0/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=None/crossover_rate=0.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/addnist/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/multnist/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=one_point/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/language/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/cifartile/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/gutenberg/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/isabella/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/geoclassing/evolution/seed=3/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
    "/localdisk/home/lericsso/code/juwels_results/results/einspace/chesseract/evolution/seed=0/backtrack=True/mode=iterative/time_limit=300/max_id_limit=10000/depth_limit=20/mem_limit=8192/load_from=None/generational=True/regularised=True/population_size=100/architecture_seed=None/mutation_strategy=random/mutation_rate=0.5/crossover_strategy=constrained_smith_waterman/crossover_rate=1.0/selection_strategy=tournament/tournament_size=10/elitism=5/search_results.pkl",
]

# %%
# number of finished experiments across datasets, algorithms and seeds
len(paths)
# Out:
# 125

# %% [markdown]
# #### Extract search results
# The following code selects the results for all experiments that reached 1000 iterations (commented out for now)

# %%
# for path in paths:
#     with open(path, "rb") as f:
#         search_history = pickle.load(f)["rewards"]
#         print(len(search_history))
#         # do something with search history

# %% [markdown]
# #### Only extract CSWX results

# %%
for path in paths:
    if "constrained_smith_waterman" in path:
        with open(path, "rb") as f:
            search_history = pickle.load(f)["rewards"]
            print(len(search_history))
            # do something with search history
            # each row in the history consists of (arch, accuracy, sample_duration, eval_duration, individual, ancestry)
            # the first 100 rows are the initial population
            for arch, accuracy, sample_duration, eval_duration, ancestry in search_history[::-1]: # get the final individual from the search
                print("Architecture:", arch[0])
                print("Accuracy:", accuracy)
                # an ancestry of None means the arch is in the initial population
                # otherwise it is a dictionary containing {
                #    "parent1": parent1_arch,
                #    "parent2": parent2_arch,
                #    "parent1_id": parent1_id,
                #    "parent2_id": parent2_id,
                #    "parent1_accuracy": parent1_accuracy,
                #    "parent2_accuracy": parent2_accuracy,
                #    "crossover": True,
                #    "crossover_strategy": 'constrained_smith_waterman'
                #    "crossover_rate": 1.0,
                #    "crossover_skewness": 0,
                #    "crossover_operations": operations_applied, # the operations that were applied to produce offspring
                #    "crossover_all_operations": all_operations, # the full list of operations on the shortest path between parent1 and parent2
                #    "crossover_distance_to_parent1": distance_to_parent1,
                #    "crossover_distance_to_parent2": distance_to_parent2,
                #    "crossover_distance_between_parents": distance_between_parents,
                #    "mutation_strategy": 'random'
                #    "mutation_rate": 0.5,
                #    "mutation": True or False, # whether the offspring was mutated after crossover
                # }
                print("Ancestry:", ancestry)
                break
            break
# Out:
# 1000
# Architecture: routing[im2col(1,1,0), sequential(routing[perm(0,2,1), branching(4){clone(4), sequential(computation<linear(1024)>, computation<relu>), add(4)}, identity], sequential(sequential(branching(4){clone(4), sequential(computation<linear(16)>, computation<linear(1024)>), add(4)}, computation<relu>), computation<linear(16)>)), perm(0,2,1)]
# Accuracy: 0.855
# ...
